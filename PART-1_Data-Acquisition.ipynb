# %% [markdown]
# # Spotify Streaming History Dashboard
# ## Part 1: Acquiring Data and Track URIs
# Summary of process:
# - Create dataframe from streaming history json files
# - Clean dataframe
# - Populate dataframe with track URIs from library json file
# - Populate remaing track URIs from Spotify Web API
# ***
# ### Install and Import Required Libraries

# %%
# !pip install spotipy
# !pip install requests
# !pip install pandas
# !pip install tqdm
# Out:
# Requirement already satisfied: spotipy in /opt/anaconda3/lib/python3.9/site-packages (2.19.0)
# Requirement already satisfied: requests>=2.25.0 in /opt/anaconda3/lib/python3.9/site-packages (from spotipy) (2.26.0)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/anaconda3/lib/python3.9/site-packages (from spotipy) (1.26.7)
# Requirement already satisfied: six>=1.15.0 in /opt/anaconda3/lib/python3.9/site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.25.0->spotipy) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.25.0->spotipy) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.9/site-packages (2.26.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from requests) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.9/site-packages (from requests) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests) (3.2)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.9/site-packages (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in /opt/anaconda3/lib/python3.9/site-packages (from pandas) (1.20.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.9/site-packages (4.62.3)

# %%
import pandas as pd
import numpy as np
import requests
import json
import random
from tqdm.notebook import tqdm_notebook
import time
import spotipy
from spotipy.oauth2 import SpotifyOAuth

# %% [markdown]
# ### Compile Database of Streaming History

# %%
# Put each streaming history json file into pd dataframe
df_file0 = pd.read_json('StreamingHistory0.json')
df_file1 = pd.read_json('StreamingHistory1.json')
df_file2 = pd.read_json('StreamingHistory2.json')
df_file3 = pd.read_json('StreamingHistory3.json')
df_file4 = pd.read_json('StreamingHistory4.json')

# Combine streaming history into one dataframe
df_streams = pd.concat([df_file0, df_file1, df_file2, df_file3, df_file4]).reset_index(drop=True)

# Put library json file into pd dataframe
with open('YourLibrary.json') as json_data:
    library = json.load(json_data)
df_library = pd.DataFrame(library['tracks'])

# %%
df_streams.tail()
# Out:
#                 endTime     artistName                           trackName  \
# 42798  2022-05-21 19:01          Wafia               Flowers & Superpowers
# 42799  2022-05-21 19:01   Hippo Campus                           Passenger
# 42800  2022-05-21 19:01          HONNE  NOW I'M ALONE (feat. Sofía Valdés)
# 42801  2022-05-21 19:06  Petit Biscuit                           Waterfall
# 42802  2022-05-21 19:06          BANKS                     Under The Table
#
#        msPlayed
# 42798     15166
# 42799      4596
# 42800     56887
# 42801     18925
# 42802    249459

# %%
df_library.head()
# Out:
#              artist                                     album      track  \
# 0  Charlotte Cardin                            Phoenix Deluxe  Sex to Me
# 1            cehryl                                 Delusions   Fractals
# 2        Mac Miller                                   Circles      Woods
# 3             BANKS                                       III    Godless
# 4     Billie Eilish  WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?    goodbye
#
#                                     uri
# 0  spotify:track:6HKtRka0CohhwAVKlTAAJH
# 1  spotify:track:0rb8uwjyGc37ZPuvLBNGrj
# 2  spotify:track:3Qa944OTMZkg8DHjET8JQv
# 3  spotify:track:1eTL8yocTmire9gpOn2H2g
# 4  spotify:track:3LgWsmilsrWXiPYQFRD0T7

# %% [markdown]
# ### Clean Dataframe and Prep for API

# %%
# Drop entries with unknown artist or unknown track
df_streams.drop(df_streams[df_streams.artistName=='Unknown Artist'].index, inplace=True)
df_streams.drop(df_streams[df_streams.trackName=='Unknown Track'].index, inplace=True)
df_streams.reset_index(drop=True, inplace=True)
df_streams.shape

# Remove songs with 0ms listening time
df_streams.drop(df_streams[df_streams.msPlayed==0].index, inplace=True)
df_streams.reset_index(inplace=True, drop=True)

# Remove extra days (we want exactly one year)
df_streams.drop(df_streams[df_streams.endTime<'2021-05-21'].index, inplace=True)
df_streams.drop(df_streams[df_streams.endTime>'2022-05-21'].index, inplace=True)
df_streams.reset_index(inplace=True, drop=True)

# Add URI column 
df_streams['uri'] = np.nan

# %%
df_streams.tail()
# Out:
#                 endTime     artistName           trackName  msPlayed  uri
# 41392  2022-05-20 23:10     Your Smith             Ooh Wee    110189  NaN
# 41393  2022-05-20 23:10     Mac Miller             Ladders     17904  NaN
# 41394  2022-05-20 23:15   Jessie Reyez  Figures, a Reprise      4110  NaN
# 41395  2022-05-20 23:15  Daniel Caesar             OPEN UP    266226  NaN
# 41396  2022-05-20 23:30         TENDER  Can't Show My Face     87796  NaN

# %%
# Remove "spotify:track:" from URI in the library dataframe
df_library['uri'] = df_library["uri"].str.split(":", expand = True)[2]
df_library.head()
# Out:
#              artist                                     album      track  \
# 0  Charlotte Cardin                            Phoenix Deluxe  Sex to Me
# 1            cehryl                                 Delusions   Fractals
# 2        Mac Miller                                   Circles      Woods
# 3             BANKS                                       III    Godless
# 4     Billie Eilish  WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?    goodbye
#
#                       uri
# 0  6HKtRka0CohhwAVKlTAAJH
# 1  0rb8uwjyGc37ZPuvLBNGrj
# 2  3Qa944OTMZkg8DHjET8JQv
# 3  1eTL8yocTmire9gpOn2H2g
# 4  3LgWsmilsrWXiPYQFRD0T7

# %%
# Populate URI column in streams df with URIs from library column
for s_i, s_row in tqdm_notebook(df_streams.iterrows()):
    for l_i, l_row in df_library.iterrows():
        if ((str(s_row['artistName']) == str(l_row['artist'])) and (str(s_row['trackName']) == str(l_row['track']))):
            df_streams['uri'][s_i] = df_library['uri'][l_i]        
            
df_streams.tail(15)
# Out:
# 0it [00:00, ?it/s]
# /var/folders/75/xf0bc_w13_l1hgbk2ljvmjf40000gn/T/ipykernel_19214/2551853950.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_streams['uri'][s_i] = df_library['uri'][l_i]
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#                 endTime     artistName           trackName  msPlayed  \
# 41382  2022-05-20 22:21   Stefflon Don            16 Shots    224727
# 41383  2022-05-20 22:24         MEDUZA        Lose Control    168387
# 41384  2022-05-20 22:24   Zara Larsson        I Would Like     14372
# 41385  2022-05-20 22:28         VÉRITÉ             save up    230794
# 41386  2022-05-20 22:32          BANKS                Burn    205970
# 41387  2022-05-20 22:33     Amber Mark      Waiting - Demo    101475
# 41388  2022-05-20 22:51     Mac Miller                2009    308871
# 41389  2022-05-20 23:04     Mac Miller                2009     40265
# 41390  2022-05-20 23:08          Michl                Self    212957
# 41391  2022-05-20 23:08          Drake        Trust Issues     19937
# 41392  2022-05-20 23:10     Your Smith             Ooh Wee    110189
# 41393  2022-05-20 23:10     Mac Miller             Ladders     17904
# 41394  2022-05-20 23:15   Jessie Reyez  Figures, a Reprise      4110
# 41395  2022-05-20 23:15  Daniel Caesar             OPEN UP    266226
# 41396  2022-05-20 23:30         TENDER  Can't Show My Face     87796
#
#                           uri
# 41382                     NaN
# 41383                     NaN
# 41384                     NaN
# 41385                     NaN
# 41386                     NaN
# 41387                     NaN
# 41388                     NaN
# 41389                     NaN
# 41390                     NaN
# 41391                     NaN
# 41392                     NaN
# 41393                     NaN
# 41394  0qynxleiY0wavOijAW9trC
# 41395  4QTwWQDW89udp0JDO2lmPI
# 41396  456UdZSHZco8pr5Mau8w3e

# %%
# Save to CSV
df_streams.to_csv('StreamingHistory_PreURI.csv', index=False)

# %%
# Check number of requests required for API
df_streams['uri'].isnull().sum()
# Out:
# 22411

# %% [markdown]
# ### Retrieve Missing URIs from Spotify Web API

# %%
df=pd.read_csv('StreamingHistory_PreURI.csv')

# %%
# Setup access for Spotify API
client_id = 'ebd35cded9324038b57d33aa816040fe'
client_secret = '4d5c594f164e475e89cb8860506c3a3e'
redirect_uri = 'http://localhost:5000/callback'
scope = 'user-read-recently-played'

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=client_id,
                                               client_secret=client_secret,
                                               redirect_uri=redirect_uri,
                                               scope=scope))

# %%
# Split df in four due to avoid timeout
df1 = df.iloc[0:11000]
df2 = df.iloc[11000:22000]
df3 = df.iloc[22000:33000]
df4 = df.iloc[33000:]


# Request URIs for first quarter
trackURI = []

for index, row in tqdm_notebook(df1.iterrows()):
    artist = row['artistName']
    track = row['trackName']
    uri = row['uri']
    if index % 200 == 0:
        time.sleep(random.uniform(3, 6))
    if pd.isnull(uri):
        query = sp.search(q='artist:' + artist + ' track:' + track, type='track')
        try:
            track_id = query['tracks']['items'][0]['id']
            trackURI.append(track_id)
        except:
            trackURI.append(np.nan)
    else:
        trackURI.append(uri)
# Out:
# 0it [00:00, ?it/s]

# %%
# Request URIs for second quarter
for index, row in tqdm_notebook(df2.iterrows()):
    artist = row['artistName']
    track = row['trackName']
    uri = row['uri']
    if index % 200 == 0:
        time.sleep(random.uniform(3, 6))
    if pd.isnull(uri):
        query = sp.search(q='artist:' + artist + ' track:' + track, type='track')
        try:
            track_id = query['tracks']['items'][0]['id']
            trackURI.append(track_id)
        except:
            trackURI.append(np.nan)
    else:
        trackURI.append(uri)
# Out:
# 0it [00:00, ?it/s]

# %%
# Request URIs for third quarter
for index, row in tqdm_notebook(df3.iterrows()):
    artist = row['artistName']
    track = row['trackName']
    uri = row['uri']
    if index % 200 == 0:
        time.sleep(random.uniform(3, 6))
    if pd.isnull(uri):
        query = sp.search(q='artist:' + artist + ' track:' + track, type='track')
        try:
            track_id = query['tracks']['items'][0]['id']
            trackURI.append(track_id)
        except:
            trackURI.append(np.nan)
    else:
        trackURI.append(uri)
# Out:
# 0it [00:00, ?it/s]

# %%
# Request URIs for fourth quarter
for index, row in tqdm_notebook(df4.iterrows()):
    artist = row['artistName']
    track = row['trackName']
    uri = row['uri']
    if index % 200 == 0:
        time.sleep(random.uniform(3, 6))
    if pd.isnull(uri):
        query = sp.search(q='artist:' + artist + ' track:' + track, type='track')
        try:
            track_id = query['tracks']['items'][0]['id']
            trackURI.append(track_id)
        except:
            trackURI.append(np.nan)
    else:
        trackURI.append(uri)
# Out:
# 0it [00:00, ?it/s]

# %%
# Update URI column
df['uri'] = trackURI
df.tail(15)
# Out:
#                 endTime     artistName           trackName  msPlayed  \
# 41382  2022-05-20 22:21   Stefflon Don            16 Shots    224727
# 41383  2022-05-20 22:24         MEDUZA        Lose Control    168387
# 41384  2022-05-20 22:24   Zara Larsson        I Would Like     14372
# 41385  2022-05-20 22:28         VÉRITÉ             save up    230794
# 41386  2022-05-20 22:32          BANKS                Burn    205970
# 41387  2022-05-20 22:33     Amber Mark      Waiting - Demo    101475
# 41388  2022-05-20 22:51     Mac Miller                2009    308871
# 41389  2022-05-20 23:04     Mac Miller                2009     40265
# 41390  2022-05-20 23:08          Michl                Self    212957
# 41391  2022-05-20 23:08          Drake        Trust Issues     19937
# 41392  2022-05-20 23:10     Your Smith             Ooh Wee    110189
# 41393  2022-05-20 23:10     Mac Miller             Ladders     17904
# 41394  2022-05-20 23:15   Jessie Reyez  Figures, a Reprise      4110
# 41395  2022-05-20 23:15  Daniel Caesar             OPEN UP    266226
# 41396  2022-05-20 23:30         TENDER  Can't Show My Face     87796
#
#                           uri
# 41382  2169IKAivSUUFGcedGASXc
# 41383  7CHi4DtfK4heMlQaudCuHK
# 41384  4Q4jmPHwu0wrJvqrld0FQ6
# 41385  6Ce5PkT2ksqbjrRmpf30UY
# 41386  7M2D3kwze7HQp99LGrbJlJ
# 41387  6sqjaO9q52sNKJ8S4x53DD
# 41388  6dFn6my1sHK2bcf23GlHwM
# 41389  6dFn6my1sHK2bcf23GlHwM
# 41390  15dbSUtZxG2m8zk6DdZnQe
# 41391  4Wjhj0WjkyECccfHVIgaTq
# 41392  3NzqnpBP4gT27QMD73GwSM
# 41393  39NDBdU5Xkm5pCFGa5kZtI
# 41394  0qynxleiY0wavOijAW9trC
# 41395  4QTwWQDW89udp0JDO2lmPI
# 41396  456UdZSHZco8pr5Mau8w3e

# %%
# Remove entries with no URI
df.dropna(subset=['uri'], inplace=True)
df.reset_index(inplace=True, drop=True)
df = df.astype({"uri": str})

# %% [markdown]
# ### Save to CSV

# %%
df.to_csv('StreamingHistory_PostURI.csv', index=False)
